# %%
import requests
response = requests.get(f"http://127.0.0.1:5000/api/health")
response.json()
# Out:
# {'device': 'cuda',
#  'model_type': 'gru',
#  'num_classes': 101,
#  'sequence_length': 32,
#  'status': 'healthy'}

# %%
# %pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.3.1
# asttokens                    3.0.1
# astunparse                   1.6.3
# brotlicffi                   1.2.0.0
# cachetools                   6.2.3
# certifi                      2025.11.12
# cffi                         2.0.0
# charset-normalizer           3.4.4
# colorama                     0.4.6
# comm                         0.2.3
# contourpy                    1.3.2
# cryptography                 43.0.3
# cycler                       0.12.1
# debugpy                      1.8.18
# decorator                    5.2.1
# exceptiongroup               1.3.1
# executing                    2.2.1
# filelock                     3.20.0
# flatbuffers                  25.9.23
# fonttools                    4.61.1
# fsspec                       2025.12.0
# gast                         0.4.0
# gmpy2                        2.2.2
# google-api-core              2.28.1
# ...

# %%
import torch
print("torch.__version__ =", torch.__version__)
print("torch.version.cuda =", torch.version.cuda)
print("torch.cuda.is_available() =", torch.cuda.is_available())
print("torch.cuda.device_count() =", torch.cuda.device_count())
if torch.cuda.is_available():
    print("device name:", torch.cuda.get_device_name(0))
# Out:
# torch.__version__ = 2.5.1
# torch.version.cuda = 12.1
# torch.cuda.is_available() = True
# torch.cuda.device_count() = 1
# device name: Quadro P620

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# absl-py                 2.3.1
# asttokens               3.0.1
# attrs                   25.4.0
# blinker                 1.9.0
# brotlicffi              1.2.0.0
# certifi                 2025.11.12
# cffi                    2.0.0
# charset-normalizer      3.4.4
# click                   8.3.1
# colorama                0.4.6
# comm                    0.2.3
# contourpy               1.3.3
# cycler                  0.12.1
# debugpy                 1.8.19
# decorator               5.2.1
# executing               2.2.1
# filelock                3.20.0
# Flask                   3.1.2
# flask-cors              6.0.2
# flatbuffers             25.12.19
# fonttools               4.61.1
# fsspec                  2025.12.0
# gmpy2                   2.2.2
# idna                    3.11
# iniconfig               2.3.0
# ipykernel               7.1.0
# ipython                 9.8.0
# ipython_pygments_lexers 1.1.1
# ...

# %%
# NOTE: Installing packages from inside the running notebook kernel can crash or
# destabilize the kernel. Run package installation in a terminal instead.
# For example (PowerShell):
# conda install pytorch torchvision torchaudio pytorch-cuda=12.1 -c pytorch -c nvidia
# Out:
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - pytorch
#  - nvidia
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\Dell\miniconda3\envs\ml_env
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=12.1
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     brotlicffi-1.2.0.0         |  py310h885b0b7_0         346 KB
#     certifi-2025.11.12         |  py310haa95532_0         154 KB
#     cffi-2.0.0                 |  py310h02ab6af_1         241 KB
#     charset-normalizer-3.4.4   |  py310haa95532_0         106 KB
#     cuda-cccl-12.9.27          |                0          16 KB  nvidia
# ...
